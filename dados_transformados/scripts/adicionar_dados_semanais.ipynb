# %%
import pandas as pd

# %%
base_atual = pd.read_csv(r"C:\\tb_banco\\base_bq.csv", sep=",",low_memory=False)

# %%
base_atual
# Out:
#             tipo  orgao_transcritor  codigo_sici            nome_orgao  \
# 0       Processo          1000440.0         4100  Gabinete do Prefeito
# 1       Processo          1000440.0         4100  Gabinete do Prefeito
# 2       Processo          1000440.0         4100  Gabinete do Prefeito
# 3       Processo          1000440.0         4100  Gabinete do Prefeito
# 4       Processo          1000440.0         4100  Gabinete do Prefeito
# ...          ...                ...          ...                   ...
# 673807  Processo         29004330.0         4000                  SMPD
# 673808  Processo         29004330.0         4000                  SMPD
# 673809  Processo         29004330.0         4000                  SMPD
# 673810  Processo         29004330.0         4000                  SMPD
# 673811  Processo         29004330.0         4000                  SMPD
#
#        numero_processo tipo_processo  numero_documento_identificador  \
# ...

# %%
novos_2001 = pd.read_csv(r"C:\tb_banco\semanal\arq2001_03-10-outubro.csv", sep=",",low_memory=False)
novos_2001
# Out:
#            Tipo  ORG. TRANSCRITOR  CODIGO SICI            Nome_Órgão  \
# 0      Processo           1020210         4100  Gabinete do Prefeito
# 1      Processo           1020210         4100  Gabinete do Prefeito
# 2      Processo           1020210         4100  Gabinete do Prefeito
# 3      Processo           1020210         4100  Gabinete do Prefeito
# 4      Processo           1020210         4100  Gabinete do Prefeito
# ...         ...               ...          ...                   ...
# 29728  Processo          27003050         3800                 SMPDA
# 29729  Processo          27003050         3800                 SMPDA
# 29730  Processo          27003050         3800                 SMPDA
# 29731  Processo          28004110         3800                 SMPDA
# 29732  Processo          29004330         3800                 SMPDA
#
#        NUM. PROCESSO TIPO PROCESSO  NUM. DOC. IDENT.  TIPO DOC. IDENT.  \
# ...

# %%
# adicionar novos_2001 a base_atual
base_atual = base_atual.append(novos_2001, ignore_index=True)
base_atual
# Out:
# C:\Users\stell\AppData\Local\Temp\ipykernel_4860\2413305404.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   base_atual = base_atual.append(novos_2001, ignore_index=True)
#             tipo  orgao_transcritor  codigo_sici            nome_orgao  \
# 0       Processo          1000440.0       4100.0  Gabinete do Prefeito
# 1       Processo          1000440.0       4100.0  Gabinete do Prefeito
# 2       Processo          1000440.0       4100.0  Gabinete do Prefeito
# 3       Processo          1000440.0       4100.0  Gabinete do Prefeito
# 4       Processo          1000440.0       4100.0  Gabinete do Prefeito
# ...          ...                ...          ...                   ...
# 703540       NaN                NaN          NaN                   NaN
# 703541       NaN                NaN          NaN                   NaN
# 703542       NaN                NaN          NaN                   NaN
# ...

# %%
novos_2296 = pd.read_csv(r"C:\tb_banco\semanal\arq2296_03-10-outubro.csv", sep=",",low_memory=False)
novos_2296
# Out:
#            Tipo  ORG. TRANSCRITOR  CODIGO SICI            Nome_Órgão  \
# 0    Expediente           1001475         4100  Gabinete do Prefeito
# 1    Expediente           3006600         2900                  SMTR
# 2    Expediente           3006600         2900                  SMTR
# 3    Expediente           4130612         1400                  SMFP
# 4    Expediente           4130612         1400                  SMFP
# ..          ...               ...          ...                   ...
# 255  Expediente          27003050         3800                 SMPDA
# 256  Expediente          27003050         3800                 SMPDA
# 257  Expediente          27003050         3800                 SMPDA
# 258  Expediente          27003050         3800                 SMPDA
# 259  Expediente          27003050         3800                 SMPDA
#
#      NUM. PROCESSO  TIPO PROCESSO  NUM. DOC. IDENT.  TIPO DOC. IDENT.  \
# ...

# %%
# adicionar novos_2296 a base_atual
base_atual = base_atual.append(novos_2296, ignore_index=True)
# Out:
# C:\Users\stell\AppData\Local\Temp\ipykernel_4860\3123179464.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   base_atual = base_atual.append(novos_2296, ignore_index=True)
# C:\Users\stell\AppData\Local\Temp\ipykernel_4860\3123179464.py:2: FutureWarning: Behavior when concatenating bool-dtype and numeric-dtype arrays is deprecated; in a future version these will cast to object dtype (instead of coercing bools to numeric values). To retain the old behavior, explicitly cast bool-dtype arrays to numeric dtype.
#   base_atual = base_atual.append(novos_2296, ignore_index=True)

# %%
base_atual
# Out:
#             tipo  orgao_transcritor  codigo_sici            nome_orgao  \
# 0       Processo          1000440.0       4100.0  Gabinete do Prefeito
# 1       Processo          1000440.0       4100.0  Gabinete do Prefeito
# 2       Processo          1000440.0       4100.0  Gabinete do Prefeito
# 3       Processo          1000440.0       4100.0  Gabinete do Prefeito
# 4       Processo          1000440.0       4100.0  Gabinete do Prefeito
# ...          ...                ...          ...                   ...
# 703800       NaN                NaN          NaN                   NaN
# 703801       NaN                NaN          NaN                   NaN
# 703802       NaN                NaN          NaN                   NaN
# 703803       NaN                NaN          NaN                   NaN
# 703804       NaN                NaN          NaN                   NaN
#
#        numero_processo tipo_processo  numero_documento_identificador  \
# ...

# %%
# salvar base_atual como .csv
base_atual.to_csv(r"C:\\tb_banco\\base_bq.csv", index=False)
